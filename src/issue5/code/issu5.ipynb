# %%
import cpfiles
import osfile
import os
import numpy as np
import cv2
import pywt # pip install pywavelets
from matplotlib import pyplot as plt

# %%
osfile.pathlocal()
# Out:
# Current Working Directory  /Users/geovannyinca/_trainer/_master/repositorio/multimedia/MCDWTold/src/issue5/code

# %%
osfile.main()
# Out:
# Current Working Directory 1: /Users/geovannyinca/_trainer/_master/repositorio/multimedia/MCDWTold/src/issue5/code
# Directory changed
# Current Working Directory 2 /Users/geovannyinca/_trainer/_master/repositorio/multimedia/MCDWTold/src

# %%
os.system("python3 -O MDWT.py -p ./issue5/img/ ")
# Out:
# 0

# %%
from IPython.core.display  import Image
Image(filename=('./issue5/img/000.png'))

# %%
im2 = cv2.imread("./issue5/img/000.png")
 
plt.imshow(im2)
a2 = np.true_divide(im2,4)
plt.figure()

plt.subplot(2, 2, 1)
plt.imshow(a2)
