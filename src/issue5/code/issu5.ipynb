# %%
import cpfiles
import osfile
import route
import os
import numpy as np
import divimg 
import pywt # pip install pywavelets
from time import sleep

# %%
cpfiles.cpfile()
extfile=".png"
factor=2
osfile.main()
# Out:
# Existe Archivo
# Current Working Directory 1: /Users/geovannyinca/_trainer/_master/repositorio/multimedia/MCDWTold/src/issue5/code
# Directory changed
# Current Working Directory 2 /Users/geovannyinca/_trainer/_master/repositorio/multimedia/MCDWTold/src

# %%
os.system("python3 -O MDWT.py -p ./issue5/img/ ")
# Out:
# 0

# %%
file=route.ls("./issue5/img/",extfile)
print(file)
# Out:
# ['000.png', '001.png', '002.png', '003.png', '004.png', 'HH000.png', 'HH001.png', 'HH002.png', 'HH003.png', 'HH004.png', 'HL000.png', 'HL001.png', 'HL002.png', 'HL003.png', 'HL004.png', 'LH000.png', 'LH001.png', 'LH002.png', 'LH003.png', 'LH004.png', 'LL000.png', 'LL001.png', 'LL002.png', 'LL003.png', 'LL004.png']

# %%
for im in file:
    #print(im)
    divimg.divimg(im,factor)
    #sleep(5)
