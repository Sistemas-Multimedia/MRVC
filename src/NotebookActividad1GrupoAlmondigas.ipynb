# %% [markdown]
# ## Create folder structure for images storing

# %%
import urllib.request
import os

path = "/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest"
originalFramesPath = "/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals"
processedFramesPath = "/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/processed"

try:
    os.mkdir(path)
except OSError:
    print ("Creation of the directory %s failed" % path)
else:
    print ("Successfully created the directory %s " % path)

try:
    os.mkdir(originalFramesPath)
except OSError:
    print ("Creation of the directory %s failed" % originalFramesPath)
else:
    print ("Successfully created the directory %s " % originalFramesPath)
    
try:
    os.mkdir(processedFramesPath)
except OSError:
    print ("Creation of the directory %s failed" % processedFramesPath)
else:
    print ("Successfully created the directory %s " % processedFramesPath)
    
urllib.request.urlretrieve('https://media.xiph.org/video/derf/y4m/foreman_qcif.y4m', path + "/foreman")
# Out:
# Successfully created the directory /home/josecarlosfuentes/Documentos/MCDWT/src/videoTest
# Successfully created the directory /home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals
# Successfully created the directory /home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/processed
# ('/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/foreman',
#  <http.client.HTTPMessage at 0x7facb2e0fa90>)

# %% [markdown]
# ## Set code for 1 iteration

# %%
import os

#Function definition for calculating folder weight
def calcular_directorio(directorio): return sum([sum([os.path.getsize(rutas+"//"+archivo) for archivo in archivos]) for rutas, _, archivos in os.walk(directorio)])

predictor=1 
iterations=1
gop = pow(2, iterations)
num_images = gop - 1

#Remove old pictures
# !rm /home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals/*.png

#Invoke ffmpeg command to extract GOP
# !ffmpeg -i '/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/foreman' -vframes $gop '/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals/'%03d.png

#Rename files
for i in range(gop):
    os.rename("/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals/00" + str(i+1) + ".png", "/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals/00" + str(i) + ".png")

#Create folder for processed images
folderPath = "/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/processed/itNum" + str(iterations)

try:
    os.mkdir(folderPath)
except OSError:
    print ("Creation of the directory %s failed" % folderPath)
else:
    print ("Successfully created the directory %s " % folderPath)
    
#Copy original images to /tmp folder for working in order place 
# !cp /home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals/*.png /tmp

#Execute compression scripts
# !python3 -O MDWT.py -p /tmp/ -N $num_images
# !python3 -O MCDWT.py -P $predictor -p /tmp/ -T $iterations -N $num_images

#Copy high sub-bands images into processed folder
# !cp /tmp/H????.png $folderPath

#Copy low sub-bands images into processed folder
# !cp /tmp/L????.png $folderPath

#Remove all PNG files from /tmp
# !rm /tmp/*.png

#Calculate wieght of folder with originals images
originalsWeight = calcular_directorio(r"/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals")
print("Peso de la carpeta con las imagenes orginales: "+str(originalsWeight))

#Calculate weight of folder with processed images
processedWeight = calcular_directorio(r"/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/processed/itNum" + str(iterations))
print("Peso de la carpeta con las imagenes orginales: "+str(processedWeight))

#Show compression ratio
print("Ratio de compresión: " + str(originalsWeight/processedWeight))
# Out:
# ffmpeg version 2.8.15-0ubuntu0.16.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 5.4.0 (Ubuntu 5.4.0-6ubuntu1~16.04.10) 20160609
#   configuration: --prefix=/usr --extra-version=0ubuntu0.16.04.1 --build-suffix=-ffmpeg --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --cc=cc --cxx=g++ --enable-gpl --enable-shared --disable-stripping --disable-decoder=libopenjpeg --disable-decoder=libschroedinger --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmodplug --enable-libmp3lame --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librtmp --enable-libschroedinger --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxvid --enable-libzvbi --enable-openal --enable-opengl --enable-x11grab --enable-libdc1394 --enable-libiec61883 --enable-libzmq --enable-frei0r --enable-libx264 --enable-libopencv
#   libavutil      54. 31.100 / 54. 31.100
#   libavcodec     56. 60.100 / 56. 60.100
#   libavformat    56. 40.101 / 56. 40.101
#   libavdevice    56.  4.100 / 56.  4.100
#   libavfilter     5. 40.101 /  5. 40.101
#   libavresample   2.  1.  0 /  2.  1.  0
#   libswscale      3.  1.101 /  3.  1.101
#   libswresample   1.  2.101 /  1.  2.101
#   libpostproc    53.  3.100 / 53.  3.100
# Input #0, yuv4mpegpipe, from '/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/foreman':
#   Duration: 00:00:10.01, start: 0.000000, bitrate: 9116 kb/s
#     Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 176x144, SAR 128:117 DAR 1408:1053, 29.97 fps, 29.97 tbr, 29.97 tbn, 29.97 tbc
# Output #0, image2, to '/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals/%03d.png':
#   Metadata:
#     encoder         : Lavf56.40.101
#     Stream #0:0: Video: png, rgb24, 176x144 [SAR 128:117 DAR 1408:1053], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc56.60.100 png
# Stream mapping:
#   Stream #0:0 -> #0:0 (rawvideo (native) -> png (native))
# Press [q] to stop, [?] for help
# frame=    2 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.06 bitrate=N/A
# video:106kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# Creation of the directory /home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/processed/itNum1 failed
# Peso de la carpeta con las imagenes orginales: 163181
# Peso de la carpeta con las imagenes orginales: 145675
# Ratio de compresión: 1.120171614896173

# %% [markdown]
# ## Set code for 2 iterations

# %%
predictor=1 
iterations=2
gop = pow(2, iterations)
num_images = gop - 1

#Remove old pictures
# !rm /home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals/*.png

#Invoke ffmpeg command to extract GOP
# !ffmpeg -i '/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/foreman' -vframes $gop '/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals/'%03d.png

#Rename files
for i in range(gop):
    os.rename("/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals/00" + str(i+1) + ".png", "/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals/00" + str(i) + ".png")

#Create folder for processed images
folderPath = "/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/processed/itNum" + str(iterations)

try:
    os.mkdir(folderPath)
except OSError:
    print ("Creation of the directory %s failed" % folderPath)
else:
    print ("Successfully created the directory %s " % folderPath)
    
#Copy original images to /tmp folder for working in order place 
# !cp /home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals/*.png /tmp

#Execute compression scripts
# !python3 -O MDWT.py -p /tmp/ -N $num_images
# !python3 -O MCDWT.py -P $predictor -p /tmp/ -T $iterations -N $num_images

#Copy high sub-bands images into processed folder
# !cp /tmp/H????.png $folderPath

#Copy low sub-bands images into processed folder
# !cp /tmp/L????.png $folderPath

#Remove all PNG files from /tmp
# !rm /tmp/*.png

#Calculate wieght of folder with originals images
originalsWeight = calcular_directorio(r"/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals")
print("Peso de la carpeta con las imagenes orginales: "+str(originalsWeight))

#Calculate weight of folder with processed images
processedWeight = calcular_directorio(r"/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/processed/itNum" + str(iterations))
print("Peso de la carpeta con las imagenes orginales: "+str(processedWeight))

#Show compression ratio
print("Ratio de compresión: " + str(originalsWeight/processedWeight))
# Out:
# ffmpeg version 2.8.15-0ubuntu0.16.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 5.4.0 (Ubuntu 5.4.0-6ubuntu1~16.04.10) 20160609
#   configuration: --prefix=/usr --extra-version=0ubuntu0.16.04.1 --build-suffix=-ffmpeg --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --cc=cc --cxx=g++ --enable-gpl --enable-shared --disable-stripping --disable-decoder=libopenjpeg --disable-decoder=libschroedinger --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmodplug --enable-libmp3lame --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librtmp --enable-libschroedinger --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxvid --enable-libzvbi --enable-openal --enable-opengl --enable-x11grab --enable-libdc1394 --enable-libiec61883 --enable-libzmq --enable-frei0r --enable-libx264 --enable-libopencv
#   libavutil      54. 31.100 / 54. 31.100
#   libavcodec     56. 60.100 / 56. 60.100
#   libavformat    56. 40.101 / 56. 40.101
#   libavdevice    56.  4.100 / 56.  4.100
#   libavfilter     5. 40.101 /  5. 40.101
#   libavresample   2.  1.  0 /  2.  1.  0
#   libswscale      3.  1.101 /  3.  1.101
#   libswresample   1.  2.101 /  1.  2.101
#   libpostproc    53.  3.100 / 53.  3.100
# Input #0, yuv4mpegpipe, from '/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/foreman':
#   Duration: 00:00:10.01, start: 0.000000, bitrate: 9116 kb/s
#     Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 176x144, SAR 128:117 DAR 1408:1053, 29.97 fps, 29.97 tbr, 29.97 tbn, 29.97 tbc
# Output #0, image2, to '/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals/%03d.png':
#   Metadata:
#     encoder         : Lavf56.40.101
#     Stream #0:0: Video: png, rgb24, 176x144 [SAR 128:117 DAR 1408:1053], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc56.60.100 png
# Stream mapping:
#   Stream #0:0 -> #0:0 (rawvideo (native) -> png (native))
# Press [q] to stop, [?] for help
# frame=    4 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.13 bitrate=N/A
# video:213kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# Creation of the directory /home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/processed/itNum2 failed
# a=2 Peso de la carpeta con las imagenes orginales: 272605
# Peso de la carpeta con las imagenes orginales: 203022
# Ratio de compresión: 1.3427362551841673

# %% [markdown]
# ## Set code for 5 iterations

# %%
predictor=1 
iterations=5
gop = pow(2, iterations)
num_images = gop - 1

#Remove old pictures
# !rm /home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals/*.png

#Invoke ffmpeg command to extract GOP
# !ffmpeg -i '/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/foreman' -vframes $gop '/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals/'%03d.png

#Rename files
# !cp /home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals/001.png /home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals/000.png 

#Create folder for processed images
folderPath = "/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/processed/itNum" + str(iterations)

try:
    os.mkdir(folderPath)
except OSError:
    print ("Creation of the directory %s failed" % folderPath)
else:
    print ("Successfully created the directory %s " % folderPath)
    
#Copy original images to /tmp folder for working in order place 
# !cp /home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals/*.png /tmp

#Execute compression scripts
# !python3 -O MDWT.py -p /tmp/ -N $num_images
# !python3 -O MCDWT.py -P $predictor -p /tmp/ -T $iterations -N $num_images

#Copy high sub-bands images into processed folder
# !cp /tmp/H????.png $folderPath

#Copy low sub-bands images into processed folder
# !cp /tmp/L????.png $folderPath

#Remove all PNG files from /tmp
# !rm /tmp/*.png

#Calculate wieght of folder with originals images
originalsWeight = calcular_directorio(r"/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals")
print("Peso de la carpeta con las imagenes orginales: "+str(originalsWeight))

#Calculate weight of folder with processed images
processedWeight = calcular_directorio(r"/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/processed/itNum" + str(iterations))
print("Peso de la carpeta con las imagenes orginales: "+str(processedWeight))

#Show compression ratio
print("Ratio de compresión: " + str(originalsWeight/processedWeight))
# Out:
# ffmpeg version 2.8.15-0ubuntu0.16.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 5.4.0 (Ubuntu 5.4.0-6ubuntu1~16.04.10) 20160609
#   configuration: --prefix=/usr --extra-version=0ubuntu0.16.04.1 --build-suffix=-ffmpeg --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --cc=cc --cxx=g++ --enable-gpl --enable-shared --disable-stripping --disable-decoder=libopenjpeg --disable-decoder=libschroedinger --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmodplug --enable-libmp3lame --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librtmp --enable-libschroedinger --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxvid --enable-libzvbi --enable-openal --enable-opengl --enable-x11grab --enable-libdc1394 --enable-libiec61883 --enable-libzmq --enable-frei0r --enable-libx264 --enable-libopencv
#   libavutil      54. 31.100 / 54. 31.100
#   libavcodec     56. 60.100 / 56. 60.100
#   libavformat    56. 40.101 / 56. 40.101
#   libavdevice    56.  4.100 / 56.  4.100
#   libavfilter     5. 40.101 /  5. 40.101
#   libavresample   2.  1.  0 /  2.  1.  0
#   libswscale      3.  1.101 /  3.  1.101
#   libswresample   1.  2.101 /  1.  2.101
#   libpostproc    53.  3.100 / 53.  3.100
# Input #0, yuv4mpegpipe, from '/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/foreman':
#   Duration: 00:00:10.01, start: 0.000000, bitrate: 9116 kb/s
#     Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 176x144, SAR 128:117 DAR 1408:1053, 29.97 fps, 29.97 tbr, 29.97 tbn, 29.97 tbc
# Output #0, image2, to '/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals/%03d.png':
#   Metadata:
#     encoder         : Lavf56.40.101
#     Stream #0:0: Video: png, rgb24, 176x144 [SAR 128:117 DAR 1408:1053], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc56.60.100 png
# Stream mapping:
#   Stream #0:0 -> #0:0 (rawvideo (native) -> png (native))
# Press [q] to stop, [?] for help
# frame=   32 fps=0.0 q=-0.0 Lsize=N/A time=00:00:01.06 bitrate=N/A
# video:1723kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# Creation of the directory /home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/processed/itNum5 failed
# a=2 a=4 a=6 a=8 a=10 a=12 a=14 a=16 a=18 a=20 a=22 a=24 a=26 a=28 a=30 a=4 a=8 a=12 a=16 a=20 a=24 a=28 a=8 a=16 a=24 a=16 Peso de la carpeta con las imagenes orginales: 1818621
# Peso de la carpeta con las imagenes orginales: 2144910
# Ratio de compresión: 0.8478775333230765

# %% [markdown]
# ## Set code for 8 iterations

# %%
predictor=1 
iterations=8
gop = pow(2, iterations)
num_images = gop - 1

#Remove old pictures
# !rm /home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals/*.png

#Invoke ffmpeg command to extract GOP
# !ffmpeg -i '/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/foreman' -vframes $gop '/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals/'%03d.png

#Rename files
# !cp /home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals/001.png /home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals/000.png 

#Create folder for processed images
folderPath = "/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/processed/itNum" + str(iterations)

try:
    os.mkdir(folderPath)
except OSError:
    print ("Creation of the directory %s failed" % folderPath)
else:
    print ("Successfully created the directory %s " % folderPath)
    
#Copy original images to /tmp folder for working in order place 
# !cp /home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals/*.png /tmp

#Execute compression scripts
# !python3 -O MDWT.py -p /tmp/ -N $num_images
# !python3 -O MCDWT.py -P $predictor -p /tmp/ -T $iterations -N $num_images

#Copy high sub-bands images into processed folder
# !cp /tmp/H????.png $folderPath

#Copy low sub-bands images into processed folder
# !cp /tmp/L????.png $folderPath

#Remove all PNG files from /tmp
# !rm /tmp/*.png

#Calculate wieght of folder with originals images
originalsWeight = calcular_directorio(r"/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals")
print("Peso de la carpeta con las imagenes orginales: "+str(originalsWeight))

#Calculate weight of folder with processed images
processedWeight = calcular_directorio(r"/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/processed/itNum" + str(iterations))
print("Peso de la carpeta con las imagenes orginales: "+str(processedWeight))

#Show compression ratio
print("Ratio de compresión: " + str(originalsWeight/processedWeight))
# Out:
# ffmpeg version 2.8.15-0ubuntu0.16.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 5.4.0 (Ubuntu 5.4.0-6ubuntu1~16.04.10) 20160609
#   configuration: --prefix=/usr --extra-version=0ubuntu0.16.04.1 --build-suffix=-ffmpeg --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --cc=cc --cxx=g++ --enable-gpl --enable-shared --disable-stripping --disable-decoder=libopenjpeg --disable-decoder=libschroedinger --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmodplug --enable-libmp3lame --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librtmp --enable-libschroedinger --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxvid --enable-libzvbi --enable-openal --enable-opengl --enable-x11grab --enable-libdc1394 --enable-libiec61883 --enable-libzmq --enable-frei0r --enable-libx264 --enable-libopencv
#   libavutil      54. 31.100 / 54. 31.100
#   libavcodec     56. 60.100 / 56. 60.100
#   libavformat    56. 40.101 / 56. 40.101
#   libavdevice    56.  4.100 / 56.  4.100
#   libavfilter     5. 40.101 /  5. 40.101
#   libavresample   2.  1.  0 /  2.  1.  0
#   libswscale      3.  1.101 /  3.  1.101
#   libswresample   1.  2.101 /  1.  2.101
#   libpostproc    53.  3.100 / 53.  3.100
# Input #0, yuv4mpegpipe, from '/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/foreman':
#   Duration: 00:00:10.01, start: 0.000000, bitrate: 9116 kb/s
#     Stream #0:0: Video: rawvideo (I420 / 0x30323449), yuv420p, 176x144, SAR 128:117 DAR 1408:1053, 29.97 fps, 29.97 tbr, 29.97 tbn, 29.97 tbc
# Output #0, image2, to '/home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/originals/%03d.png':
#   Metadata:
#     encoder         : Lavf56.40.101
#     Stream #0:0: Video: png, rgb24, 176x144 [SAR 128:117 DAR 1408:1053], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc
#     Metadata:
#       encoder         : Lavc56.60.100 png
# Stream mapping:
#   Stream #0:0 -> #0:0 (rawvideo (native) -> png (native))
# Press [q] to stop, [?] for help
# frame=  256 fps=0.0 q=-0.0 Lsize=N/A time=00:00:08.54 bitrate=N/A
# video:13825kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# Successfully created the directory /home/josecarlosfuentes/Documentos/MCDWT/src/videoTest/processed/itNum8
# a=2 a=4 a=6 a=8 a=10 a=12 a=14 a=16 a=18 a=20 a=22 a=24 a=26 a=28 a=30 a=32 a=34 a=36 a=38 a=40 a=42 a=44 a=46 a=48 a=50 a=52 a=54 a=56 a=58 a=60 a=62 a=64 a=66 a=68 a=70 a=72 a=74 a=76 a=78 a=80 a=82 a=84 a=86 a=88 a=90 a=92 a=94 a=96 a=98 a=100 a=102 a=104 a=106 a=108 a=110 a=112 a=114 a=116 a=118 a=120 a=122 a=124 a=126 a=128 a=130 a=132 a=134 a=136 a=138 a=140 a=142 a=144 a=146 a=148 a=150 a=152 a=154 a=156 a=158 a=160 a=162 a=164 a=166 a=168 a=170 a=172 a=174 a=176 a=178 a=180 a=182 a=184 a=186 a=188 a=190 a=192 a=194 a=196 a=198 a=200 a=202 a=204 a=206 a=208 a=210 a=212 a=214 a=216 a=218 a=220 a=222 a=224 a=226 a=228 a=230 a=232 a=234 a=236 a=238 a=240 a=242 a=244 a=246 a=248 a=250 a=252 a=254 a=4 a=8 a=12 a=16 a=20 a=24 a=28 a=32 a=36 a=40 a=44 a=48 a=52 a=56 a=60 a=64 a=68 a=72 a=76 a=80 a=84 a=88 a=92 a=96 a=100 a=104 a=108 a=112 a=116 a=120 a=124 a=128 a=132 a=136 a=140 a=144 a=148 a=152 a=156 a=160 a=164 a=168 a=172 a=176 a=180 a=184 a=188 a=192 a=196 a=200 a=204 a=208 a=212 a=216 a=220 a=224 a=228 a=232 a=236 a=240 a=244 a=248 a=252 a=8 a=16 a=24 a=32 a=40 a=48 a=56 a=64 a=72 a=80 a=88 a=96 a=104 a=112 a=120 a=128 a=136 a=144 a=152 a=160 a=168 a=176 a=184 a=192 a=200 a=208 a=216 a=224 a=232 a=240 a=248 a=16 a=32 a=48 a=64 a=80 a=96 a=112 a=128 a=144 a=160 a=176 a=192 a=208 a=224 a=240 a=32 a=64 a=96 a=128 a=160 a=192 a=224 a=64 a=128 a=192 a=128 Peso de la carpeta con las imagenes orginales: 14210858
# Peso de la carpeta con las imagenes orginales: 17803265
# Ratio de compresión: 0.7982163945770622
